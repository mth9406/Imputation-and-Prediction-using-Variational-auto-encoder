# %%
# !python ./main/main.py -h
# Out:
# usage: main.py [-h] [--data_type DATA_TYPE] [--data_path DATA_PATH] [--tr TR]
#                [--val VAL] [--standardize] [--prob PROB]
#                [--batch_size BATCH_SIZE] [--epoch EPOCH] [--lr LR]
#                [--patience PATIENCE] [--delta DELTA]
#                [--print_log_option PRINT_LOG_OPTION]
#                [--imp_loss_penalty IMP_LOSS_PENALTY] [--model_path MODEL_PATH]
#                [--input_size INPUT_SIZE] [--n_labels N_LABELS]
#                [--drop_p DROP_P] [--test] [--model_file MODEL_FILE]
#                [--model_type MODEL_TYPE]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --data_type DATA_TYPE
#                         one of: gestures, elec, wind
#   --data_path DATA_PATH
#   --tr TR               the ratio of training data to the original data
#   --val VAL             the ratio of validation data to the original data
#   --standardize         standardize the inputs if it is true.
# ...

# %%
# gestures
# !python ./main/main.py --data_type gestures --data_path ./data/gesture --standardize --batch_size 512 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 10 --model_path data/gesture/si --input_size 18 --n_labels 5 --model_type si
# Out:
# Namespace(batch_size=512, data_path='./data/gesture', data_type='gestures', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=0.01, input_size=18, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/gesture/si', model_type='si', n_labels=5, patience=10, print_log_option=10, prob=0.1, standardize=True, test=False, tr=0.7, val=0.2)
# The path already exists, skip making the path...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9901 entries, 0 to 1447
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lhx     9901 non-null   float64
#  1   lhy     9901 non-null   float64
#  2   lhz     9901 non-null   float64
#  3   rhx     9901 non-null   float64
#  4   rhy     9901 non-null   float64
#  5   rhz     9901 non-null   float64
#  6   hx      9901 non-null   float64
#  7   hy      9901 non-null   float64
#  8   hz      9901 non-null   float64
#  9   sx      9901 non-null   float64
# ...

# %%
# elec
# !python ./main/main.py --data_type elec --data_path ./data/elec --standardize --batch_size 512 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 10 --model_path data/gesture/si --input_size 8 --n_labels 3 --model_type si
# Out:
# ^C

# %%
# wind
# !python ./main/main.py --data_type wind --data_path ./data/wind_turbin_power --standardize --batch_size 1024 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 10 --model_path data/gesture/si --input_size 76 --n_labels 1 --model_type si
# Out:
# Namespace(batch_size=1024, data_path='./data/wind_turbin_power', data_type='wind', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=0.01, input_size=76, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/gesture/si', model_type='si', n_labels=1, patience=10, print_log_option=10, prob=0.1, standardize=True, test=False, tr=0.7, val=0.2)
# The path already exists, skip making the path...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136730 entries, 0 to 136729
# Data columns (total 78 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   Timestamp                                          136730 non-null  object
#  1   Gearbox_T1_High_Speed_Shaft_Temperature            132779 non-null  float64
#  2   Gearbox_T3_High_Speed_Shaft_Temperature            132438 non-null  float64
# ...

# %%
import pandas as pd 
import os  

data_path = './data/mobile'
data_file = os.path.join(data_path, 'train.csv')
data = pd.read_csv(data_file)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
# mobile
# !python ./main/main.py --data_type mobile --data_path ./data/mobile --standardize --batch_size 128 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 10 --model_path data/mobile/si --input_size 20 --n_labels 4 --model_type ai
# Out:
# Namespace(batch_size=128, data_path='./data/mobile', data_type='mobile', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=0.01, input_size=20, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/mobile/si', model_type='ai', n_labels=4, patience=10, print_log_option=10, prob=0.1, standardize=True, test=False, tr=0.7, val=0.2)
# The path already exists, skip making the path...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
# ...

# %%
# !python ./main/main.py --data_type mobile --data_path ./data/mobile --standardize --batch_size 128 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 10 --model_path data/mobile/vai --input_size 20 --n_labels 4 --model_type vai --vai_n_samples 1
# Out:
# Namespace(batch_size=128, data_path='./data/mobile', data_type='mobile', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=0.01, input_size=20, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/mobile/vai', model_type='vai', n_labels=4, patience=10, print_log_option=10, prob=0.1, standardize=True, test=False, tr=0.7, vai_n_samples=1, val=0.2)
# The path already exists, skip making the path...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
# ...

# %%
# mobile
# !python ./main/main.py --data_type mobile --data_path ./data/mobile --standardize --batch_size 128 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 1 --model_path data/mobile/vai --input_size 20 --n_labels 4 --model_type vai
# Out:
# Namespace(batch_size=128, data_path='./data/mobile', data_type='mobile', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=0.01, input_size=20, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/mobile/vai', model_type='vai', n_labels=4, patience=10, print_log_option=1, prob=0.1, standardize=True, test=False, tr=0.7, vai_n_samples=100, val=0.2)
# The path already exists, skip making the path...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
# ...

# %%
# !python ./main/main.py --data_type mobile --data_path ./data/mobile --standardize --batch_size 128 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 1 --model_path data/mobile/ai --input_size 20 --n_labels 4 --model_type ai
# Out:
# Namespace(batch_size=128, data_path='./data/mobile', data_type='mobile', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=0.01, input_size=20, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/mobile/ai', model_type='ai', n_labels=4, patience=10, print_log_option=1, prob=0.1, standardize=True, test=False, tr=0.7, vai_n_samples=100, val=0.2)
# Making a path to save the model...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
# ...

# %%
# !python ./main/main.py --data_type mobile --data_path ./data/mobile --standardize --batch_size 128 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 1 --model_path data/mobile/vai --input_size 20 --n_labels 4 --model_type vai
# Out:
# Namespace(batch_size=128, data_path='./data/mobile', data_type='mobile', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=0.01, input_size=20, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/mobile/si', model_type='si', n_labels=4, patience=10, print_log_option=1, prob=0.1, standardize=True, test=False, tr=0.7, vai_n_samples=100, val=0.2)
# The path already exists, skip making the path...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
# ...

# %%
# !python main/main.py --data_type mobile --data_path ./data/mobile --standardize --batch_size 128 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 1 --model_path data/mobile/vai --input_size 20 --n_labels 4 --model_type vai --num_folds 2
# Out:
# Namespace(batch_size=128, data_path='./data/mobile', data_type='mobile', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=0.01, input_size=20, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/mobile/vai', model_type='vai', n_labels=4, num_folds=2, patience=10, print_log_option=1, prob=0.1, standardize=True, test=False, tr=0.7, vai_n_samples=100, val=0.2)
# The path already exists, skip making the path...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
# ...

# %%
# !python main/main.py --data_type mobile --data_path ./data/mobile --standardize --batch_size 128 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 1 --model_path data/mobile/vai --input_size 20 --n_labels 4 --model_type vai --num_folds 1 --test_all_missing --test_n_missing 2
# Out:
# Namespace(batch_size=128, data_path='./data/mobile', data_type='mobile', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=1.0, input_size=20, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/mobile/vai', model_type='vai', n_labels=4, num_folds=1, patience=10, print_log_option=1, prob=0.1, stack_fc_lyrs=False, standardize=True, test=False, test_all_missing=True, test_n_missing=2, tr=0.7, vai_n_samples=100, val=0.2)
# The path already exists, skip making the path...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
# ...

# %% [markdown]
# # Wind

# %%
# wind
# !python ./main/main.py --data_type wind --data_path ./data/wind_turbin_power --input_size 76 --n_labels 1  --standardize --batch_size 128 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 10 --model_path data/wind_turbin_power/model --model_type vai --vai_n_samples 100
# Out:
# Namespace(batch_size=128, data_path='./data/wind_turbin_power', data_type='wind', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=0.01, input_size=76, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/wind_turbin_power/model', model_type='vai', n_labels=1, patience=10, print_log_option=10, prob=0.1, standardize=True, test=False, tr=0.7, vai_n_samples=100, val=0.2)
# The path already exists, skip making the path...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15584 entries, 0 to 136716
# Data columns (total 78 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Timestamp                                          15584 non-null  object
#  1   Gearbox_T1_High_Speed_Shaft_Temperature            15584 non-null  float64
#  2   Gearbox_T3_High_Speed_Shaft_Temperature            15584 non-null  float64
# ...

# %%
# !python main/main.py --data_type pulsar --data_path ./data/pulsar --standardize --batch_size 128 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 1 --model_path data/pulsar/vai --input_size 20 --n_labels 4 --model_type vai --stack_fc_lyrs --num_folds 1 --test_all_missing --test_n_missing 2
# Out:
# Namespace(batch_size=128, data_path='./data/pulsar', data_type='pulsar', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=1.0, input_size=20, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/pulsar/vai', model_type='vai', n_labels=4, num_folds=1, patience=10, print_log_option=1, prob=0.1, stack_fc_lyrs=True, standardize=True, test=False, test_all_missing=True, test_n_missing=2, tr=0.7, vai_n_samples=100, val=0.2)
# The path already exists, skip making the path...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2306 entries, 0 to 2305
# Data columns (total 9 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0    Mean of the integrated profile                2306 non-null   float64
#  1    Standard deviation of the integrated profile  2306 non-null   float64
# ...

# %%
# !python main/main.py --data_type pulsar --data_path ./data/pulsar --standardize --batch_size 128 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 1 --model_path data/pulsar/vai --input_size 20 --n_labels 4 --model_type vai --num_folds 1 --test_all_missing --test_n_missing 2
# Out:
# Namespace(batch_size=128, data_path='./data/pulsar', data_type='pulsar', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=1.0, input_size=20, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/pulsar/vai', model_type='vai', n_labels=4, num_folds=1, patience=10, print_log_option=1, prob=0.1, stack_fc_lyrs=False, standardize=True, test=False, test_all_missing=True, test_n_missing=2, tr=0.7, vai_n_samples=100, val=0.2)
# The path already exists, skip making the path...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2306 entries, 0 to 2305
# Data columns (total 9 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0    Mean of the integrated profile                2306 non-null   float64
#  1    Standard deviation of the integrated profile  2306 non-null   float64
# ...

# %%
# !python main/main.py --data_type faults --data_path ./data/faults --standardize --batch_size 128 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 1 --model_path data/faults/vai --input_size 20 --n_labels 4 --model_type vai --num_folds 1 --test_all_missing --test_n_missing 2
# Out:
# Namespace(batch_size=128, data_path='./data/faults', data_type='faults', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=1.0, input_size=20, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/faults/vai', model_type='vai', n_labels=4, num_folds=1, patience=10, print_log_option=1, prob=0.1, stack_fc_lyrs=False, standardize=True, test=False, test_all_missing=True, test_n_missing=2, tr=0.7, vai_n_samples=100, val=0.2)
# The path already exists, skip making the path...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1941 entries, 0 to 1940
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   X_Minimum              1941 non-null   int64
#  1   X_Maximum              1941 non-null   int64
#  2   Y_Minimum              1941 non-null   int64
#  3   Y_Maximum              1941 non-null   int64
#  4   Pixels_Areas           1941 non-null   int64
# ...

# %%
import pandas as pd  
df = pd.read_csv('./data/wine/WineQT.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df['quality'].unique() -3
# Out:
# array([2, 3, 4, 1, 5, 0], dtype=int64)

# %%
import numpy as np

# %%
import pandas as pd
data = pd.read_csv('./data/abalone/abalone_csv.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sex                    4177 non-null   object
#  1   Length                 4177 non-null   float64
#  2   Diameter               4177 non-null   float64
#  3   Height                 4177 non-null   float64
#  4   Whole_weight           4177 non-null   float64
#  5   Shucked_weight         4177 non-null   float64
#  6   Viscera_weight         4177 non-null   float64
#  7   Shell_weight           4177 non-null   float64
#  8   Class_number_of_rings  4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(data.iloc[:,1:-1], data.iloc[:, -1])
# Out:
# LinearRegression()

# %%
lr.score(data.iloc[:, 1:-1], data.iloc[:, -1])
# Out:
# 0.5276299399919837

# %%
df.dtypes
# Out:
# X_Minimum                  int64
# X_Maximum                  int64
# Y_Minimum                  int64
# Y_Maximum                  int64
# Pixels_Areas               int64
# X_Perimeter                int64
# Y_Perimeter                int64
# Sum_of_Luminosity          int64
# Minimum_of_Luminosity      int64
# Maximum_of_Luminosity      int64
# Length_of_Conveyer         int64
# TypeOfSteel_A300           int64
# TypeOfSteel_A400           int64
# Steel_Plate_Thickness      int64
# Edges_Index              float64
# Empty_Index              float64
# Square_Index             float64
# Outside_X_Index          float64
# Edges_X_Index            float64
# Edges_Y_Index            float64
# Outside_Global_Index     float64
# LogOfAreas               float64
# Log_X_Index              float64
# Log_Y_Index              float64
# Orientation_Index        float64
# Luminosity_Index         float64
# SigmoidOfAreas           float64
# Pastry                     int64
# ...

# %%
df.head()
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0         42         50     270900     270944           267           17
# 1        645        651    2538079    2538108           108           10
# 2        829        835    1553913    1553931            71            8
# 3        853        860     369370     369415           176           13
# 4       1289       1306     498078     498335          2409           60
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0           44              24220                     76
# 1           30              11397                     84
# 2           19               7972                     99
# 3           45              18996                     99
# 4          260             246930                     37
#
#    Maximum_of_Luminosity  ...  Orientation_Index  Luminosity_Index  \
# 0                    108  ...             0.8182           -0.2913
# ...

# %%
targets = ['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']

# %%
n, p = df.shape
classes = np.zeros((n,))
for i, target in enumerate(targets):
    idx = (df[target] == 1)
    classes[idx] = i

# %%
classes
# Out:
# array([0., 0., 0., ..., 6., 6., 6.])

# %%
df = df.drop(targets, axis=1)

# %%
df['faults'] = classes

# %%
df.head()
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0         42         50     270900     270944           267           17
# 1        645        651    2538079    2538108           108           10
# 2        829        835    1553913    1553931            71            8
# 3        853        860     369370     369415           176           13
# 4       1289       1306     498078     498335          2409           60
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0           44              24220                     76
# 1           30              11397                     84
# 2           19               7972                     99
# 3           45              18996                     99
# 4          260             246930                     37
#
#    Maximum_of_Luminosity  ...  Edges_X_Index  Edges_Y_Index  \
# 0                    108  ...         0.4706         1.0000
# ...

# %%
# !python main/main.py --data_type mobile --data_path ./data/mobile --standardize --batch_size 128 --epoch 1 --lr 3e-4 --patience 10 --print_log_option 1 --model_path data/mobile/vai --input_size 20 --n_labels 4 --model_type vibi --num_folds 1 --test_all_missing --test_n_missing 2
# Out:
# Namespace(batch_size=128, data_path='./data/mobile', data_type='mobile', delta=0.0, drop_p=0.5, epoch=1, imp_loss_penalty=1.0, input_size=20, kl_weight=0.1, lr=0.0003, model_file='latest_checkpoint.pth.tar', model_path='data/mobile/vai', model_type='vibi', n_labels=4, num_folds=1, patience=10, print_log_option=1, prob=0.1, stack_fc_lyrs=False, standardize=True, test=False, test_all_missing=True, test_n_missing=2, tr=0.7, vai_n_samples=100, val=0.2)
# The path already exists, skip making the path...
# Loading data...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
# ...

# %%
import torch 
torch.FloatTensor([1])[0].shape
# Out:
# torch.Size([])

# %%
torch.FloatTensor(1).shape
# Out:
# torch.Size([1])
